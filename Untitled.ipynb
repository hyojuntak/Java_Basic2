# %%
age = int(input("몇살? "))
if age < 19:
    print('애들은 가라')
# Out:
# 몇살? 2
# 애들은 가라

# %%
a = 3
if a == 3:
    print("3이다")
if a >= 5:
    print("5보다 크다")
if a != 5:
    print("5보다 작다")
# Out:
# 3이다
# 5보다 작다

# %%
country = "Korea"
if country == "Korea":
    print("한국입니다.")
if country == "korea":
    print("대한민국입니다.")
# Out:
# 한국입니다.

# %%
a = 3
if a > 1 and a < 10:
    print("OK")
    
if a<1 or a == 2:
    print("No")

a = 3
if 1 < a < 10:
    print("Ok")
# Out:
#   File "<ipython-input-14-34e07b2cdbb9>", line 13
#     if a || 1 or a ==3
#           ^
# SyntaxError: invalid syntax

# %%
age = 22
if age < 19:
    print("애들은 가라")
else:
    print("어서 옵쇼")
# Out:
# 어서 옵쇼

# %%
age = 22 
if age < 19 : 
    print("애들은 가라")
elif age < 25:
    print("대학생입니다.")
else:
    print("어서옵쇼")
# Out:
# 대학생입니다.

# %%
age = 23
if age < 19:
    print("애들은 가라")
else: 
    if age < 25:
        print("대학생입니다.")
    else:
        print("어서옵쇼")
# Out:
# 대학생입니다.

# %%
money = 6500
if money >=20000:
    print("탕수육을 먹는다.")
elif money >= 10000:
    print("쟁반 짜장을 먹는다.")
elif money >= 6000:
    print("짬뽕을 먹는다.")

else:    
    print("단무지를 먹는다.")
# Out:
# 짬뽕을 먹는다.

# %%
money = 6500
if money >= 20000:
    print("탕수육을 먹는다.")
else:
    if money >=10000:
        print("쟁반 짜장을 먹는다.")
    if money >= 6000:
        print("짬뽕을 먹는다.")
    if money >= 4000:
        print("짜장을 먹는다.")
    else:
        print("단무지를 먹는다.")
# Out:
# 짬뽕을 먹는다.
# 짜장을 먹는다.

# %%
man = True
age = 22
if man == True:
    if age >= 19:
        print("성인 남자입니다.")
    else: 
        print("성인 남자가 아닙니다.")
# Out:
# 성인 남자입니다.

# %% [markdown]
# man = True
# age = 22
# if man == True:
#     if age >= 19:
#         print("성인 남자입니다.")
#     else:
#         print("소년입니다.")

# %%
student = 1
while student <=5:
    print(student, "번 학생의 성적을 처리한다.")
    student += 1
# Out:
# 1 번 학생의 성적을 처리한다.
# 2 번 학생의 성적을 처리한다.
# 3 번 학생의 성적을 처리한다.
# 4 번 학생의 성적을 처리한다.
# 5 번 학생의 성적을 처리한다.

# %%
number = 1
sum = 0
while number <=100:
    sum += number
    number += 1
    print('sum =',sum )
# Out:
# sum = 1
# sum = 3
# sum = 6
# sum = 10
# sum = 15
# sum = 21
# sum = 28
# sum = 36
# sum = 45
# sum = 55
# sum = 66
# sum = 78
# sum = 91
# sum = 105
# sum = 120
# sum = 136
# sum = 153
# sum = 171
# sum = 190
# sum = 210
# sum = 231
# sum = 253
# sum = 276
# sum = 300
# sum = 325
# sum = 351
# sum = 378
# sum = 406
# sum = 435
# sum = 465
# sum = 496
# sum = 528
# sum = 561
# sum = 595
# sum = 630
# sum = 666
# sum = 703
# sum = 741
# sum = 780
# sum = 820
# sum = 861
# sum = 903
# sum = 946
# sum = 990
# sum = 1035
# sum = 1081
# sum = 1128
# sum = 1176
# sum = 1225
# sum = 1275
# sum = 1326
# sum = 1378
# sum = 1431
# sum = 1485
# sum = 1540
# sum = 1596
# sum = 1653
# sum = 1711
# sum = 1770
# sum = 1830
# sum = 1891
# sum = 1953
# sum = 2016
# sum = 2080
# sum = 2145
# sum = 2211
# sum = 2278
# sum = 2346
# sum = 2415
# sum = 2485
# sum = 2556
# sum = 2628
# sum = 2701
# sum = 2775
# sum = 2850
# sum = 2926
# sum = 3003
# sum = 3081
# sum = 3160
# sum = 3240
# sum = 3321
# sum = 3403
# sum = 3486
# sum = 3570
# sum = 3655
# sum = 3741
# sum = 3828
# sum = 3916
# sum = 4005
# sum = 4095
# sum = 4186
# sum = 4278
# sum = 4371
# sum = 4465
# sum = 4560
# sum = 4656
# sum = 4753
# sum = 4851
# sum = 4950
# sum = 5050

# %%
for student in [1,2,3,4,5]:
        print(student, "번 학생의 성적을 처리한다.")
# Out:
# 1 번 학생의 성적을 처리한다.
# 2 번 학생의 성적을 처리한다.
# 3 번 학생의 성적을 처리한다.
# 4 번 학생의 성적을 처리한다.
# 5 번 학생의 성적을 처리한다.

# %%
sum = 0
for num in range(1,101):
    sum += num 
print ("sum = ", sum)
# Out:
# sum =  5050

# %%
for student in range(1,6):
    print(student, "번 학생의 성적을 처리한다.")
# Out:
# 1 번 학생의 성적을 처리한다.
# 2 번 학생의 성적을 처리한다.
# 3 번 학생의 성적을 처리한다.
# 4 번 학생의 성적을 처리한다.
# 5 번 학생의 성적을 처리한다.

# %%
sum = 0 
for num in range(2,101, 2):
    sum += num 
print(sum)
# Out:
# 2550

# %%
for x in range(1, 51):
    if x % 10 == 0:
        print("+" ,end= '')
    else:
        print("-", end= '')


for x in range(1,51):
    if x % 10 == 0:
        print("+")
    else:
        print("-")
# Out:
# ---------+---------+---------+---------+---------+-
# -
# -
# -
# -
# -
# -
# -
# -
# +
# -
# -
# -
# -
# -
# -
# -
# -
# -
# +
# -
# -
# -
# -
# -
# -
# -
# -
# -
# +
# -
# -
# -
# -
# -
# -
# -
# -
# -
# +
# -
# -
# -
# -
# -
# -
# -
# -
# -
# +

# %%
for num in range (1, 51):
    if num % 10 == 0:
        print("+", end= '')
    else:
        print("-", end= '')
# Out:
# ---------+---------+---------+---------+---------+

# %%
x = 1
while x < 51:
    if x % 10 == 0:
        print("+",end='')
    else:
        print("-", end='')
